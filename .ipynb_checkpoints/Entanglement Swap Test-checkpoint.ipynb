# %%
from qiskit import *
from qiskit import QuantumCircuit
from qiskit import IBMQ
from qiskit import transpile
import numpy as np
from qiskit.tools.monitor import job_monitor, backend_monitor, backend_overview
from qiskit.providers.aer import AerSimulator
import numpy as np
from qiskit.quantum_info import state_fidelity
from qiskit.providers.aer import noise
from qiskit.utils.mitigation import CompleteMeasFitter, complete_meas_cal
from qiskit_experiments.library import StateTomography
from qiskit.visualization import array_to_latex

# %%
from qiskit import Aer
aer_sim = Aer.get_backend('aer_simulator')
aer_state = Aer.get_backend('statevector_simulator')

# %%
IBMQ.load_account()
provider = IBMQ.get_provider('ibm-q')
manila_real = provider.get_backend('ibmq_manila')

# %%
manila_sim = AerSimulator.from_backend(manila_real)

# %%
initial_epr = QuantumCircuit(5, 5)

#Hadmard gate on 
initial_epr.h(1)
# #cnot gate on 0 and 1
initial_epr.cx(1, 2)
# #Hadmard gate on 
initial_epr.h(3)
# #cnot gate on 0 and 1
initial_epr.cx(3, 4)
#draw the circuit
# initial_epr.h(0)
# initial_epr.cx(0, 3)
initial_epr.draw('mpl')

# %%
bell_state_measurement = QuantumCircuit(5, 5)

#CNOT gate on 1 and 2
bell_state_measurement.cx(2, 3)
#Hadamard on 1
bell_state_measurement.h(2)
#barrier to seperate measurement
bell_state_measurement.barrier((2, 3))
#add z measurement
bell_state_measurement.measure((2 , 3), (2, 3))
# bell_state_measurement.x(4).c_if(3, 1)
# bell_state_measurement.z(4).c_if(2, 1)
bell_state_measurement.cx(3, 4)
bell_state_measurement.cz(2, 4)
#add barrier so BSM happens before CHSH
bell_state_measurement.barrier(range(5))
#bell_state_measurement.draw('mpl')

# %%
bell_state_measurement_AC = QuantumCircuit(5, 5)

#CNOT gate on 1 and 2
bell_state_measurement_AC.cx(1, 4)
#Hadamard on 1
bell_state_measurement_AC.h(1)
#barrier to seperate measurement
bell_state_measurement_AC.barrier(range(5))
#add z measurement
bell_state_measurement_AC.measure((1 , 4), (1, 4))
bell_state_measurement_AC.draw('mpl')

# %%
circuit = initial_epr + bell_state_measurement
# circuit.reset((2,3))
# Out:
# <ipython-input-8-9e9bd1cb249a>:1: DeprecationWarning: The QuantumCircuit.__add__() method is being deprecated.Use the compose() method which is more flexible w.r.t circuit register compatibility.
#   circuit = initial_epr + bell_state_measurement

# %%
circuit.draw('mpl')

# %%
bell = QuantumCircuit(2,2)
bell.h(0)
bell.cx(0,1)

# %%
job = aer_state.run(bell)
psi_bell = job.result().get_statevector(bell)
print(psi_bell)
# Out:
# Statevector([0.70710678+0.j, 0.        +0.j, 0.        +0.j,
#              0.70710678+0.j],
#             dims=(2, 2))

# %%
transpile(circuit, manila_real).draw('mpl')

# %%
#generate the calibration circuits
# meas_calibs, state_labels = .complete_meas_cal(qubit_list=[1,4])

# job_cal = aer_sim.run(transpile(circuit, manila_real), shots=15000)

# meas_fitter = CompleteMeasFitter(job_cal.result(),state_labels)

tomo_bell = StateTomography(transpile(circuit, manila_real), measurement_qubits=[1, 4])
tomo_bell.analysis.set_options(fitter='linear_inversion')
tomo_bell.analysis.set_options(target=psi_bell)
#no correction


#correct data
# correct_tomo_results = meas_fitter.filter.apply(job_tomo.result(), method='least_squares')
# tomo_bell = StateTomographyFitter(correct_tomo_results, qst_bell)
# rho_bell = tomo_bell.fit()
# F_bell = state_fidelity(psi_bell, rho_bell)

# %%
# rho_bell = tomo_bell.run(backend=manila_real)

# %%
tomo_bell.run_options
# Out:
# Options(meas_level=<MeasLevel.CLASSIFIED: 2>)

# %%
# print(rho_bell.analysis_results("state"))

# %%
# rho_bell_density = rho_bell.analysis_results("state").value

# %%
from qiskit.ignis.verification.tomography import state_tomography_circuits, StateTomographyFitter
from qiskit.ignis.verification.tomography import process_tomography_circuits, ProcessTomographyFitter
from qiskit.ignis.verification.tomography import gateset_tomography_circuits, GatesetTomographyFitter
import qiskit.ignis.mitigation.measurement as mc
import qiskit.quantum_info as qi
import time

# %%
# Create a state preparation circuit
q5 = QuantumRegister(2)
bell5 = QuantumCircuit(q5)
bell5.h(q5[0])
for j in range(1):
    bell5.cx(q5[j], q5[j + 1])

# Get ideal output state
# target_state_bell5 = qi.Statevector.from_instruction(bell5, (1, 4))

# Generate circuits and run on simulator
t = time.time()
qst_bell5 = state_tomography_circuits(circuit, [1, 4])
job = execute(transpile(qst_bell5, manila_real), manila_sim, shots=5000)

# Extract tomography data so that counts are indexed by measurement configuration
tomo_bell5 = StateTomographyFitter(job.result(), qst_bell5)
print('Time taken:', time.time() - t)
# Out:
# Time taken: 3.7903878688812256

# %%
print(tomo_bell5)
# Out:
# <qiskit.ignis.verification.tomography.fitters.state_fitter.StateTomographyFitter object at 0x7f2888317790>

# %%
t = time.time()
rho_fit_bell5 = tomo_bell5.fit(method='lstsq')
print('Time taken:', time.time() - t)
print('State fidelity: F = {:.5f}'.format(qi.state_fidelity(rho_fit_bell5, DensityMatrix(bell))))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-45b0e96f7da1> in <module>
#       1 t = time.time()
# ----> 2 rho_fit_bell5 = tomo_bell5.fit(method='lstsq')
#       3 print('Time taken:', time.time() - t)
#       4 print('State fidelity: F = {:.5f}'.format(qi.state_fidelity(rho_fit_bell5, DensityMatrix(bell))))
#
# ~/.local/lib/python3.8/site-packages/qiskit/ignis/verification/tomography/fitters/state_fitter.py in fit(self, method, standard_weights, beta, **kwargs)
#     120             \text{vec}(\text{rho}) - \text{data}||_2`.
#     121         """
# --> 122         return super().fit(method, standard_weights, beta,
#     123                            trace=1, psd=True, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py in fit(self, method, standard_weights, beta, psd, trace, trace_preserving, **kwargs)
#     218                 method = 'lstsq'
#     219         if method == 'lstsq':
# --> 220             return lstsq_fit(data, basis_matrix,
#     221                              weights=weights,
#     222                              psd=psd,
#
# ~/.local/lib/python3.8/site-packages/qiskit/ignis/verification/tomography/fitters/lstsq_fit.py in lstsq_fit(data, basis_matrix, weights, psd, trace)
#      98
#      99     # Perform least squares fit using Scipy.linalg lstsq function
# --> 100     rho_fit, _, _, _ = lstsq(meas_matrix, exp_values)
#     101
#     102     # Reshape fit to a density matrix
#
# ~/.local/lib/python3.8/site-packages/scipy/linalg/basic.py in lstsq(a, b, cond, overwrite_a, overwrite_b, check_finite, lapack_driver)
#    1145     """
#    1146     a1 = _asarray_validated(a, check_finite=check_finite)
# -> 1147     b1 = _asarray_validated(b, check_finite=check_finite)
#    1148     if len(a1.shape) != 2:
#    1149         raise ValueError('Input array a should be 2D')
#
# ~/.local/lib/python3.8/site-packages/scipy/_lib/_util.py in _asarray_validated(a, check_finite, sparse_ok, objects_ok, mask_ok, as_inexact)
#     291             raise ValueError('masked arrays are not supported')
#     292     toarray = np.asarray_chkfinite if check_finite else np.asarray
# --> 293     a = toarray(a)
#     294     if not objects_ok:
#     295         if a.dtype is np.dtype('O'):
#
# ~/anaconda3/envs/csq/lib/python3.8/site-packages/numpy/lib/function_base.py in asarray_chkfinite(a, dtype, order)
#     601     a = asarray(a, dtype=dtype, order=order)
#     602     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 603         raise ValueError(
#     604             "array must not contain infs or NaNs")
#     605     return a
#
# ValueError: array must not contain infs or NaNs

# %%
plot_state_city(rho_fit_bell5)

# %%
# tomo_bell.run_options

# %%
from qiskit.visualization import plot_state_city
# plot_state_city(psi_bell)

# %%
# plot_state_city(rho_bell_density)

# %%
# type(rho_bell_density)

# %%
# F_bell = state_fidelity(psi_bell, rho_bell_density)
# print('Fit Fidelity (no correction) =', F_bell)

# %%
rho_bell = tomo_bell.run(backend=aer_sim)

# %%
rho_bell_density = rho_bell.analysis_results("state").value

# %%
tomo_bell.analysis_options
# Out:
# Options(figure_names=None, measurement_basis=<PauliMeasurementBasis: PauliMeasurementBasis>, preparation_basis=None, measurement_qubits=None, preparation_qubits=None, fitter='linear_inversion', fitter_options={}, rescale_positive=True, rescale_trace=True, target=Statevector([0.70710678+0.j, 0.        +0.j, 0.        +0.j,
#              0.70710678+0.j],
#             dims=(2, 2)))

# %%
rho_bell.analysis_results()
# Out:
# [AnalysisResult(name=state, value=DensityMatrix([[ 0.49498121+0.00000000e+00j,  0.01169599-1.04720279e-02j,
#                  -0.00315289-3.44072971e-03j,  0.49459838-1.76954189e-02j],
#                 [ 0.01169599+1.04720279e-02j,  0.00178856+1.35525272e-20j,
#                   0.0006807 -2.21242657e-03j,  0.00969571+1.07072623e-02j],
#                 [-0.00315289+3.44072971e-03j,  0.0006807 +2.21242657e-03j,
#                   0.0037069 +2.16840434e-19j, -0.00533624+1.16681091e-04j],
#                 [ 0.49459838+1.76954189e-02j,  0.00969571-1.07072623e-02j,
#                  -0.00533624-1.16681091e-04j,  0.49952333-3.46944695e-18j]],
#                dims=(2, 2)), device_components=[<Qubit(Q0)>, <Qubit(Q1)>, <Qubit(Q2)>, <Qubit(Q3)>, <Qubit(Q4)>], experiment_id=65b56bf0-c39e-433a-b8f3-0d78c59d2e1b, result_id=06a16f52-44a7-4af8-bbec-25d0e00665c1, chisq=None, quality=None, verified=False, extra={'trace': 1.0000000000000018, 'eigvals': array([0.99267116, 0.00732884, 0.        , 0.        ]), 'raw_eigvals': array([ 1.00083869,  0.01549638,  0.00155528, -0.01789035]), 'rescaled_psd': True, 'fitter_metadata': {'fitter': 'linear_inversion', 'fitter_time': 0.019186973571777344}}, tags=[], experiment id='65b56bf0-c39e-433a-b8f3-0d78c59d2e1b'),
#  AnalysisResult(name=state_fidelity, value=0.9918506490756032, device_components=[<Qubit(Q0)>, <Qubit(Q1)>, <Qubit(Q2)>, <Qubit(Q3)>, <Qubit(Q4)>], experiment_id=65b56bf0-c39e-433a-b8f3-0d78c59d2e1b, result_id=afb26946-0419-482e-a972-f9f69cb4149d, chisq=None, quality=None, verified=False, extra={}, tags=[], experiment id='65b56bf0-c39e-433a-b8f3-0d78c59d2e1b'),
#  AnalysisResult(name=positive, value=True, device_components=[<Qubit(Q0)>, <Qubit(Q1)>, <Qubit(Q2)>, <Qubit(Q3)>, <Qubit(Q4)>], experiment_id=65b56bf0-c39e-433a-b8f3-0d78c59d2e1b, result_id=8d5cc8c0-d6c2-4835-88c3-86cbdd382331, chisq=None, quality=None, verified=False, extra={}, tags=[], experiment id='65b56bf0-c39e-433a-b8f3-0d78c59d2e1b')]

# %%
from qiskit.quantum_info import Statevector, DensityMatrix
plot_state_city(DensityMatrix(bell))

# %%
plot_state_city(rho_bell_density)

# %%
F_bell = state_fidelity(psi_bell, rho_bell_density)
print('Fit Fidelity (no correction) =', F_bell)
# Out:
# Fit Fidelity (no correction) = 0.9918506490756032

# %%
circuit.cx(1, 4)
circuit.h(1)
circuit.measure(1, 1)
circuit.measure(4, 4)
circuit.draw('mpl')

# %%
qr = QuantumRegister(5)
meas_calibs, state_labels = complete_meas_cal(qr=qr, circlabel='mcal')
cal_results = manila_sim.run(transpile(meas_calibs, manila_real), shots=10000).result()

meas_fitter = CompleteMeasFitter(cal_results, state_labels, circlabel='mcal')
array_to_latex(meas_fitter.cal_matrix)
# Out:
# $$
#
# \begin{bmatrix}
# 0.9214 & 0.0381 & 0.0353 & 0.0016 & \cdots & 0 & 0 & 0  \\
#  0.0118 & 0.898 & 0.0004 & 0.0353 & \cdots & 0 & 0 & 0  \\
#  0.0192 & 0.0008 & 0.9073 & 0.0329 & \cdots & 0 & 0.0001 & 0  \\
#  0.0001 & 0.0187 & 0.0114 & 0.884 & \cdots & 0 & 0 & 0  \\
#  \vdots & \vdots & \vdots & \vdots & \ddots & \vdots & \vdots & \vdots \\
#  0 & 0 & 0 & 0 & \cdots & 0.8392 & 0.0006 & 0.0302  \\
#  0 & 0 & 0 & 0 & \cdots & 0.0007 & 0.8473 & 0.0341  \\
#  0 & 0 & 0 & 0 & \cdots & 0.0165 & 0.0101 & 0.8255  \\
#  \end{bmatrix}
# $$

# %%
results = manila_sim.run(transpile(circuit, manila_real), shots=10000).result()

#Get the filter object
meas_filter = meas_fitter.filter

# Results with mitigation
mitigated_results = meas_filter.apply(results)
mitigated_counts = mitigated_results.get_counts()
noisy_counts = results.get_counts()

# %%
transpile(circuit, manila_real).draw('mpl')

# %%
manila_sim_job = manila_sim.run(transpile(circuit, manila_real), shots=10000)
aer_sim_job = aer_sim.run(transpile(circuit, manila_real), shots=10000)

# %%
# Grab the results from the job.
aer_sim_result = aer_sim_job.result().get_counts()
manila_sim_result = manila_sim_job.result().get_counts()

# %%
def prob_epr_pairs(circuit_counts):
    no_shots = sum(circuit_counts[outcome] for outcome in circuit_counts)
    
    zz = 0
    zo = 0
    oz = 0
    oo = 0
    
    for element in circuit_counts:
        if int(element[0]) == 0 and int(element[3]) == 0:
            zz += circuit_counts[element]
            
        if int(element[0]) == 0 and int(element[3]) == 1:
            zo += circuit_counts[element]
            
        if int(element[0]) == 1 and int(element[3]) == 0:
            oz += circuit_counts[element]
            
        if int(element[0]) == 1 and int(element[3]) == 1:
            oo += circuit_counts[element]
            
    return np.array([zz, zo, oz, oo]) / no_shots

# %%
print("Mixed State probabilities")
prob = prob_epr_pairs(manila_sim_result)
print(f"zz: {prob[0]}")
print(f"zo: {prob[1]}")
print(f"oz: {prob[2]}")
print(f"oo: {prob[3]}")
# Out:
# Mixed State probabilities
# zz: 0.8692
# zo: 0.0719
# oz: 0.0444
# oo: 0.0145

# %%
from qiskit.visualization import plot_histogram
plot_histogram(manila_sim_result)

# %%
print("Mixed State probabilities")
prob = prob_epr_pairs(noisy_counts)
print(f"zz: {prob[0]}")
print(f"zo: {prob[1]}")
print(f"oz: {prob[2]}")
print(f"oo: {prob[3]}")
# Out:
# Mixed State probabilities
# zz: 0.874
# zo: 0.068
# oz: 0.0447
# oo: 0.0133

# %%
print("Mixed State probabilities")
prob = prob_epr_pairs(mitigated_counts)
print(f"zz: {prob[0]}")
print(f"zo: {prob[1]}")
print(f"oz: {prob[2]}")
print(f"oo: {prob[3]}")
# Out:
# Mixed State probabilities
# zz: 0.9084216224316929
# zo: 0.04839547502015937
# oz: 0.033885633658057523
# oo: 0.00929726889009033
